# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeRegressor, plot_tree

df = pd.read_csv('weather_forecast.csv')
df
# Out:
#      Outlook Temperature Humidity   Windy Play
# 0      Sunny         Hot     High    Weak   No
# 1      Sunny         Hot     High  Strong   No
# 2   Overcast         Hot     High    Weak  Yes
# 3       Rain        Mild     High    Weak  Yes
# 4       Rain        Cool   Normal    Weak  Yes
# 5       Rain        Cool   Normal  Strong   No
# 6   Overcast        Cool   Normal  Strong  Yes
# 7      Sunny        Mild     High    Weak   No
# 8      Sunny        Cool   Normal    Weak  Yes
# 9       Rain        Mild   Normal    Weak  Yes
# 10     Sunny        Mild   Normal  Strong  Yes
# 11  Overcast        Mild     High  Strong  Yes
# 12  Overcast         Hot   Normal    Weak  Yes
# 13      Rain        Mild     High  Strong   No

# %%
temp = {
    'Hot':2,
    'Mild':1,
    'Cool':0
}

humid = {
    'High':1,
    'Normal':0
}

wind = {
    'Strong':1,
    'Weak':0
}

play ={
    'Yes':1,
    'No':0
}
outlook = {
    'Sunny': 2,
    'Overcast': 1,
    'Rain': 0
}

# %%
df['Temperature'] = df['Temperature'].replace(temp)
df['Humidity'] = df['Humidity'].replace(humid)
df['Windy'] = df['Windy'].replace(wind)
df['Play'] = df['Play'].replace(play)
df['Outlook'] = df['Outlook'].replace(outlook)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_24168\3995002391.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Temperature'] = df['Temperature'].replace(temp)
# C:\Users\admin\AppData\Local\Temp\ipykernel_24168\3995002391.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Humidity'] = df['Humidity'].replace(humid)
# C:\Users\admin\AppData\Local\Temp\ipykernel_24168\3995002391.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Windy'] = df['Windy'].replace(wind)
# C:\Users\admin\AppData\Local\Temp\ipykernel_24168\3995002391.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Play'] = df['Play'].replace(play)
# C:\Users\admin\AppData\Local\Temp\ipykernel_24168\3995002391.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Outlook'] = df['Outlook'].replace(outlook)

# %%
y = df['Play']
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     1
# 10    1
# 11    1
# 12    1
# 13    0
# Name: Play, dtype: int64

# %%
X = df.drop('Play', axis=1)
X
# Out:
#     Outlook  Temperature  Humidity  Windy
# 0         2            2         1      0
# 1         2            2         1      1
# 2         1            2         1      0
# 3         0            1         1      0
# 4         0            0         0      0
# 5         0            0         0      1
# 6         1            0         0      1
# 7         2            1         1      0
# 8         2            0         0      0
# 9         0            1         0      0
# 10        2            1         0      1
# 11        1            1         1      1
# 12        1            2         0      0
# 13        0            1         1      1

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

c4_5 = DecisionTreeClassifier(criterion='entropy', max_depth=2, random_state=0)
c4_5.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=2, random_state=0)

# %%
plt.figure(figsize=(12,14))
tree.plot_tree(c4_5, feature_names= X.columns.tolist(), class_names=['Bad', 'Good'], filled=True, rounded=True)
plt.savefig('./c4_5_tree.png', bbox_inches="tight")
